# %% [markdown]
# <a href="https://colab.research.google.com/github/viichoma/DIO-TAREFAS/blob/main/YOLO11_DetectingFaces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Instalando dependencias

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.57 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3gstjUeThPjpTen0j907")
project = rf.workspace("labomba").project("detecting-faces-395fw")
version = project.version(1)
dataset = version.download("yolov11")

# %%
# Treinar o modelo já pre-treinando reutilizando seus conhecimentos
# !yolo train model=yolo11n.pt data=/content/Detecting-faces-1/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.57 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Prever
# Prevendo utilizando o modelo

# %%
# !yolo predict model='/content/runs/detect/train2/weights/best.pt' source='/content/images.jpeg'
# Out:
# Ultralytics 8.3.57 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/images.jpeg: 384x640 1 leon, 51.3ms
# Speed: 3.3ms preprocess, 51.3ms inference, 587.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict15
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
